# %%
import airavata_experiments as ae

# %%
## generating the stimulus

### @taylor - code to generate different stimuli

# %%
## simulating on v1
for i in range(10):
    exp = ae.neuro.V1.initialize(
        name="neuro-v1",
        lgn_spikes = V1.SpikeInput("lgn_spikes/test.h5"),
        bkg_spikes = V1.SpikeInput("bkg_spikes/test.h5"),
        injcur_spikes = None,
        duration: int,
        dt: int,
        injcur_spikes: Optional[SpikeInput] = None,
    )
    exp.run()
    exp.download(f"/output_dir/{i}")

# %%
## analyzing / visualizing v1 simulation output

### @ code to visualize simulation outputs
